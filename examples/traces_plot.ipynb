# %%
from math import pi
import numpy as np
import fastplotlib as fpl
import pygfx as gfx
import cmap

from scaviz.graphics import SequenceGraphic
from scaviz.controllers import SplitXYController
# Out:
# Detected skylake derivative running on mesa i915. Clears to srgb textures will use manual shader clears.
# Detected skylake derivative running on mesa i915. Clears to srgb textures will use manual shader clears.
# Detected skylake derivative running on mesa i915. Clears to srgb textures will use manual shader clears.
# Image(value=b'version https://git-lfs.github.com/spec/...', height='55', width='300')
# <b>Available devices:</b><table><tr><th>Valid</th><th>Device</th><th>Type</th><th>Backend</th><th>Driver</th></tr><tr title="This adapter can be used with fastplotlib"><td>✅ (default) </td><td>Intel(R) Xe Graphics (TGL GT2)</td><td>IntegratedGPU</td><td>Vulkan</td><td>Mesa 24.2.8-1ubuntu1~24.04.1</td></tr><tr title="CPU rendering support is limited and mainly for testing purposes"><td>❗ limited</td><td>llvmpipe (LLVM 19.1.1, 256 bits)</td><td>CPU</td><td>Vulkan</td><td>Mesa 24.2.8-1ubuntu1~24.04.1 (LLVM 19.1.1)</td></tr><tr title="This adapter cannot be used with fastplotlib"><td>❌</td><td>Mesa Intel(R) Xe Graphics (TGL GT2)</td><td>IntegratedGPU</td><td>OpenGL</td><td>4.6 (Core Profile) Mesa 24.2.8-1ubuntu1~24.04.1</td></tr></table>
# Detected skylake derivative running on mesa i915. Clears to srgb textures will use manual shader clears.
# Detected skylake derivative running on mesa i915. Clears to srgb textures will use manual shader clears.

# %%
# Fake traces
N_TRACES = 3
N = 10**7
x = np.linspace(0, N, N, dtype=np.float32)
a0 = N / 1000
np0 = 30
t0 = N / np0
t1 = 100
phases = np.linspace(0, 1.1 * pi, N_TRACES)

print("Generating traces...", end="", flush=True)
noise = np.sin(2 * pi / t1 * x) * (a0 / 10)
ys = [np.sin(2 * pi / t0 * x - p) * a0 + noise for p in phases]
print("done.")
# Out:
# Generating traces...done.

# %%
colormap = cmap.Colormap("seaborn:tab10")

fig = fpl.Figure(size=(700, 560))
fig[0, 0].camera = gfx.OrthographicCamera(
    depth_range=(-1e3, 1e3), maintain_aspect=False
)
fig[0, 0].controller = SplitXYController()
# Out:
# RFBOutputContext()
# Detected skylake derivative running on mesa i915. Clears to srgb textures will use manual shader clears.

# %%
print("Generating graphics...", end="", flush=True)
seq_graphics = [
    fig[0, 0].add_graphic(SequenceGraphic(y, color=c))
    for y, c in zip(ys, colormap.color_stops.colors)
]
print("done.")
# Out:
# Generating graphics...done.

# %%
fig.show(maintain_aspect=False)
# Out:
# JupyterRenderCanvas(css_height='560.0px', css_width='700.0px')
